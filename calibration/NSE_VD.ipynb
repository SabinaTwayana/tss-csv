# %%
import numpy as np
import pandas as pd

def nse(simulated, observed):
  """Calculate the Nash-Sutcliffe efficiency.

  Args:
    simulated: The simulated discharge data.
    observed: The observed discharge data.

  Returns:
    The NSE value.
  """
  sum_squared_error = np.sum((simulated - observed)**2)
  sum_squared_residual = np.sum((observed - np.mean(observed))**2)
  nse = 1 - sum_squared_error / sum_squared_residual
  # print("mean",np.mean(observed))
  # print("sum:",sum_squared_error)
  # print("sum2",sum_squared_residual)
  return nse


def volume_difference(simulated, observed):
  """Calculate the volume difference between simulated and observed discharge.

  Args:
    simulated: The simulated discharge data.
    observed: The observed discharge data.

  Returns:
    The volume difference.
  """
  simulated_volume = np.sum(simulated)
  observed_volume= np.sum(observed)
  volume_difference = (simulated_volume - observed_volume)/ simulated_volume*100
  return volume_difference

if __name__ == "__main__":
  # Load the simulated and observed discharge data.
  simulated = pd.read_csv(r"D:\GDM_MODEL_1\GDM Model-DISTRIBUTION PACK\GDM Model\calibrationandvalidataion\calibration\simulated_data_2000-2008.csv")
  observed = pd.read_csv(r"D:\GDM_MODEL_1\GDM Model-DISTRIBUTION PACK\GDM Model\calibrationandvalidataion\calibration\observed_data_2000-2008_edited_tc-3.csv")
  # print("Simulated Columns:", simulated.columns)
  # print("Observed Columns:", observed.columns)
  # Calculate the NSE and volume difference.
  # nse_value1= nse(simulated["265"], observed["265"])
  # volume_difference1 = volume_difference(simulated["265"], observed["265"])
  nse_value2= nse(simulated["sim"], observed["obs"])
  volume_difference2 = volume_difference(simulated["sim"], observed["obs"])
  # nse_value3= nse(simulated["270"], observed["270"])
  # volume_difference3 = volume_difference(simulated["270"], observed["270"])

  # Print the results.
  # print("NSE1:", nse_value1)
  print("NSE2:",round(nse_value2,3))
  # print("NSE3:", nse_value3)
  # print("Volume difference1:", volume_difference1)
  print("Volume difference2:", volume_difference2)
  # print("Volume difference3:", volume_difference3)
# Out:
# NSE2: 0.863
# Volume difference2: -15.747718006558175

# %%
import matplotlib.pyplot as plt

    
    # Adding labels and title
plt.xlabel('Year')
# plt.ylabel('Discharge(m^3/s)')
plt.title('Observed vs Simulated Discharge')
plt.plot(observed['obs'])
plt.plot (simulated['sim'])
# plt.plot(observed['obs'],label = 'Observed')
# plt.plot (simulated['sim'], label='Simulated')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Assuming observed and simulated have a 'Date' column containing datetime objects
# Plotting observed and simulated data
plt.plot(observed['Date'], observed['obs'], label='obs')
plt.plot(simulated['Date'], simulated['sim'], label='sim')

# Adding legend
plt.legend()

# Customize x-axis to be formatted as dates
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))  # Format the ticks as Year-Month-Day
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks at yearly intervals

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Enable grid for x-axis according to date
# plt.gca().xaxis.grid(True)

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Plotting observed and simulated data
plt.plot(observed['obs'], label='obs')
plt.plot(simulated['sim'], label='sim')

# Adding legend
plt.legend()

# Customize x-axis ticks to be formatted as dates
plt.gca().xaxis.set_major_locator(mdates.YearLocator())  # Set major ticks at yearly intervals
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # Format the ticks as years

# Enable grid for x-axis according to date
# plt.gca().xaxis.grid(True)

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming observed and simulated DataFrames have a 'Date' column containing date strings
# Convert the 'Date' column to datetime objects
observed['Date'] = pd.to_datetime(observed['Date'])
simulated['Date'] = pd.to_datetime(simulated['Date'])

# Plotting observed and simulated data
plt.plot(observed['Date'], observed['obs'], label='Observed')
plt.plot(simulated['Date'], simulated['sim'], label='Simulated')

# Adding labels, legend, and title
plt.xlabel('Date')
plt.ylabel('Discharge(m^3/s)')
plt.title('Observed vs Simulated Discharge')
plt.legend()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Plotting observed and simulated data
plt.plot(observed['Date'], observed['obs'], label='Observed')
plt.plot(simulated['Date'], simulated['sim'], label='Simulated')

# Customize x-axis labels
# plt.xticks(rotation=45)  # Rotate x-axis labels for better readability

# Adding labels, legend, and title
plt.xlabel('Year')
plt.ylabel('Discharge(m^3/s)')
plt.title('Observed vs Simulated Discharge')

# Show legend at the bottom
plt.legend(loc='lower center', bbox_to_anchor=(0.5, -0.23), shadow=True, ncol=2, fancybox=True)

# Show plot
plt.show()
